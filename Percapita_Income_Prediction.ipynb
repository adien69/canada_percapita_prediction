# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn import linear_model

# %%
df = pd.read_csv("homeprice.csv")
df.head(10)
# Out:
#    year       income
# 0  1970  3399.299037
# 1  1971  3768.297935
# 2  1972  4251.175484
# 3  1973  4804.463248
# 4  1974  5576.514583
# 5  1975  5998.144346
# 6  1976  7062.131392
# 7  1977  7100.126170
# 8  1978  7247.967035
# 9  1979  7602.912681

# %%
# %matplotlib inline 
plt.xlabel("year",fontsize=20) 
plt.ylabel("Income(US$)",fontsize=20) 
plt.scatter(df.year, df.income, color="red",marker="+") 
# plt.grid(True)
# plt.show()

# %%
reg = linear_model.LinearRegression()
reg.fit(df[["year"]],df["income"])
# Out:
# LinearRegression()

# %%
prediction = reg.predict([[2023]]) 
prediction
# Out:
# C:\Users\Himani\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([43774.08932009])

# %%
# %matplotlib inline 
plt.xlabel("year",fontsize=20) 
plt.ylabel("Income(US$)",fontsize=20) 
plt.scatter(df.year, df.income, color="blue",marker="+")  
plt.plot(df.year,reg.predict(df[["year"]]),color="red")
# plt.grid(True)
# plt.show()
